# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\prabp\Downloads\Campus+placement+predictor+-Code+Files\Code Files\Placement_Data_Full_Class.csv')
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
# seperating the categorical and numerical columns

catvars = list(df.select_dtypes(include=['object']).columns)

numvars = list(df.select_dtypes(include=['int32','int64','float32','float64']).columns)


print(catvars,numvars)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status'] ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# ### Handling Null values

# %%
df.shape
# Out:
# (215, 15)

# %%
def plotdistplot(col):
    
    plt.figure(figsize=(15,7))
    sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
    sn.distplot(df[col],kde=True,hist=False,label=col,color='black')

# %%
mostfreq = list(dict(df['salary'].value_counts()).items())[0]
mostfreq
# Out:
# (300000.0, 22)

# %%
df['salary'].mode()[0]
# Out:
# 300000.0

# %%
df['salary_mean'] = df['salary'].fillna(df['salary'].mean())
df['salary_median'] = df['salary'].fillna(df['salary'].median())
df['salary_mode'] = df['salary'].fillna(df['salary'].mode()[0])
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#      salary_mean  salary_median  salary_mode
# 0  270000.000000       270000.0     270000.0
# 1  200000.000000       200000.0     200000.0
# 2  250000.000000       250000.0     250000.0
# 3  288655.405405       265000.0     300000.0
# 4  425000.000000       425000.0     425000.0

# %%
sallist = ['salary_mean','salary_median','salary_mode']
for sal in sallist:
    plotdistplot(sal)
# Out:
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# filling the salary with mean

df['salary'] = df['salary'].fillna(df['salary'].mean())
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000
#
#      salary_mean  salary_median  salary_mode
# 0  270000.000000       270000.0     270000.0
# 1  200000.000000       200000.0     200000.0
# 2  250000.000000       250000.0     250000.0
# 3  288655.405405       265000.0     300000.0
# 4  425000.000000       425000.0     425000.0

# %%
df = df.drop(columns=['salary_mean', 'salary_median', 'salary_mode'],axis=1)
df.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
sn.countplot(df['status'],palette='plasma')
# Out:
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
def valuecount(col):
    
    return dict(df[col].value_counts())

def getcountplot(col):
    
    sn.countplot(df[col],palette='plasma')
    plt.xticks(rotation = '45',fontweight = 'bold',fontsize = '10')
    plt.yticks(rotation = '45',fontweight = 'bold',fontsize = '10')
    plt.show()
    

for col in catvars:
    print(f'Count Plot for feature {col} is shown ↓')
    getcountplot(col)
    print('='*75)
# Out:
# Count Plot for feature gender is shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ===========================================================================
# Count Plot for feature ssc_b is shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ===========================================================================
# Count Plot for feature hsc_b is shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ===========================================================================
# Count Plot for feature hsc_s is shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ===========================================================================
# Count Plot for feature degree_t is shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ===========================================================================
# Count Plot for feature workex is shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ===========================================================================
# Count Plot for feature specialisation is shown ↓
# ===========================================================================
# Count Plot for feature status is shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ===========================================================================

# %%
getfinaldict = {}
for col in catvars:
    getfinaldict[col] = valuecount(col)
    
getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
# top science students placed

df[(df['degree_t']=='Sci&Tech')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 0    150    151      M  71.00  Central  58.66  Central  Science     58.00
# 1     77     78      M  64.00   Others  80.00   Others  Science     65.00
# 2    163    164      M  63.00   Others  67.00   Others  Science     64.00
# 3    174    175      M  73.24   Others  50.83   Others  Science     64.27
# 4     53     54      M  80.00   Others  70.00   Others  Science     72.00
#
#    degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Sci&Tech    Yes     56.0        Mkt&Fin  61.30  Placed  690000.0
# 1  Sci&Tech    Yes     69.0        Mkt&Fin  57.65  Placed  500000.0
# 2  Sci&Tech     No     75.0        Mkt&Fin  66.46  Placed  500000.0
# 3  Sci&Tech    Yes     64.0        Mkt&Fin  66.23  Placed  500000.0
# 4  Sci&Tech     No     87.0         Mkt&HR  71.04  Placed  450000.0

# %%
# top Comm&Mgt students placed

df[(df['degree_t']=='Comm&Mgmt')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    119    120      M   60.8  Central   68.4  Central  Commerce      64.6
# 1    177    178      F   73.0  Central   97.0   Others  Commerce      79.0
# 2      4      5      M   85.8  Central   73.6  Central  Commerce      73.3
# 3     95     96      M   73.0  Central   78.0   Others  Commerce      65.0
# 4    210    211      M   80.6   Others   82.0   Others  Commerce      77.6
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2  Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3  Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4  Comm&Mgmt     No    91.00        Mkt&Fin  74.49  Placed  400000.0

# %%
# max and min salary
# observation : max salary : 9,40,000 and min salary : 2,00,000

df[(df['salary']==max(df['salary'])) | (df['salary']==min(df['salary']))]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 15      16      F  65.00  Central  75.00  Central  Commerce     69.00
# 44      45      F  77.00   Others  73.00   Others  Commerce     81.00
# 50      51      F  75.20  Central  73.20  Central   Science     68.40
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 135    136      F  72.00  Central  56.00   Others   Science     69.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 1     Sci&Tech    Yes    86.50        Mkt&Fin  66.28  Placed  200000.0
# 15   Comm&Mgmt    Yes    72.00        Mkt&Fin  64.66  Placed  200000.0
# 44   Comm&Mgmt    Yes    89.00        Mkt&Fin  69.70  Placed  200000.0
# 50   Comm&Mgmt     No    65.00         Mkt&HR  62.98  Placed  200000.0
# 107  Comm&Mgmt     No    80.00         Mkt&HR  73.52  Placed  200000.0
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 135  Comm&Mgmt     No    55.60         Mkt&HR  65.63  Placed  200000.0

# %%
# students with salary more than avg salary science dept

df[(df['degree_t']=='Sci&Tech')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     150    151      M  71.00  Central  58.66  Central   Science     58.00
# 1      77     78      M  64.00   Others  80.00   Others   Science     65.00
# 2     174    175      M  73.24   Others  50.83   Others   Science     64.27
# 3     163    164      M  63.00   Others  67.00   Others   Science     64.00
# 4      53     54      M  80.00   Others  70.00   Others   Science     72.00
# 5      39     40      M  81.00   Others  68.00   Others   Science     64.00
# 6     145    146      M  89.40   Others  65.66   Others   Science     71.25
# 7     128    129      M  80.40  Central  73.40  Central   Science     77.72
# 8      22     23      F  69.80   Others  60.80   Others   Science     72.23
# 9      24     25      M  76.50   Others  97.70   Others   Science     78.86
# 10     70     71      M  82.00   Others  61.00   Others   Science     62.00
# 11    178    179      M  68.00   Others  56.00   Others   Science     68.00
# 12    153    154      M  49.00   Others  59.00   Others   Science     65.00
# 13     37     38      F  79.00  Central  76.00  Central   Science     65.60
# 14     83     84      M  84.00   Others  79.00   Others   Science     68.00
# 15     84     85      M  70.00  Central  63.00   Others   Science     70.00
# 16    160    161      M  87.00  Central  74.00  Central   Science     65.00
# 17     23     24      F  77.40   Others  60.00   Others   Science     64.74
# 18    158    159      M  67.00   Others  63.00   Others   Science     64.00
# 19    173    174      F  52.00   Others  52.00   Others   Science     55.00
# 20    169    170      M  59.96   Others  42.16   Others   Science     61.26
# 21    167    168      M  67.90   Others  62.00   Others   Science     67.00
# 22    175    176      M  63.00   Others  62.00   Others   Science     65.00
# 23    179    180      F  77.80  Central  64.00  Central   Science     64.20
# 24      3      4      M  56.00  Central  52.00  Central   Science     52.00
# 25    106    107      M  61.08   Others  50.00   Others   Science     54.00
# 26    111    112      M  51.00   Others  54.00   Others   Science     61.00
# 27    109    110      M  52.00  Central  63.00   Others   Science     65.00
# 28      5      6      M  55.00   Others  49.80   Others   Science     67.25
# 29    105    106      M  59.00  Central  64.00   Others   Science     58.00
# 30     99    100      M  54.00  Central  82.00   Others  Commerce     63.00
# 31     79     80      F  69.00  Central  62.00  Central   Science     66.00
# 32     68     69      F  69.70  Central  47.00  Central  Commerce     72.70
# 33     45     46      F  76.00  Central  64.00  Central   Science     72.00
# 34     31     32      F  67.00  Central  53.00  Central   Science     65.00
# 35    181    182      M  62.00  Central  60.33   Others   Science     64.21
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Sci&Tech    Yes    56.00        Mkt&Fin  61.30      Placed  690000.000000
# 1   Sci&Tech    Yes    69.00        Mkt&Fin  57.65      Placed  500000.000000
# 2   Sci&Tech    Yes    64.00        Mkt&Fin  66.23      Placed  500000.000000
# 3   Sci&Tech     No    75.00        Mkt&Fin  66.46      Placed  500000.000000
# 4   Sci&Tech     No    87.00         Mkt&HR  71.04      Placed  450000.000000
# 5   Sci&Tech     No    93.00        Mkt&Fin  62.56      Placed  411000.000000
# 6   Sci&Tech     No    72.00         Mkt&HR  63.23      Placed  400000.000000
# 7   Sci&Tech    Yes    81.20         Mkt&HR  76.26      Placed  400000.000000
# 8   Sci&Tech     No    55.53         Mkt&HR  68.81      Placed  360000.000000
# 9   Sci&Tech     No    97.40        Mkt&Fin  74.01      Placed  360000.000000
# 10  Sci&Tech     No    89.00        Mkt&Fin  65.45      Placed  360000.000000
# 11  Sci&Tech     No    73.00         Mkt&HR  68.07      Placed  350000.000000
# 12  Sci&Tech    Yes    86.00        Mkt&Fin  62.48      Placed  340000.000000
# 13  Sci&Tech     No    58.00         Mkt&HR  55.47      Placed  320000.000000
# 14  Sci&Tech    Yes    84.00        Mkt&Fin  66.69      Placed  300000.000000
# 15  Sci&Tech    Yes    55.00        Mkt&Fin  62.00      Placed  300000.000000
# 16  Sci&Tech    Yes    75.00         Mkt&HR  72.29      Placed  300000.000000
# 17  Sci&Tech    Yes    92.00        Mkt&Fin  63.62      Placed  300000.000000
# 18  Sci&Tech     No    60.00        Mkt&Fin  61.87  Not Placed  288655.405405
# 19  Sci&Tech     No    67.00         Mkt&HR  59.32  Not Placed  288655.405405
# 20  Sci&Tech     No    54.48         Mkt&HR  65.48  Not Placed  288655.405405
# 21  Sci&Tech    Yes    58.10        Mkt&Fin  75.71  Not Placed  288655.405405
# 22  Sci&Tech     No    87.50         Mkt&HR  60.69  Not Placed  288655.405405
# 23  Sci&Tech     No    75.50         Mkt&HR  72.14  Not Placed  288655.405405
# 24  Sci&Tech     No    66.00         Mkt&HR  59.43  Not Placed  288655.405405
# 25  Sci&Tech     No    71.00        Mkt&Fin  65.69  Not Placed  288655.405405
# 26  Sci&Tech     No    60.00         Mkt&HR  60.64  Not Placed  288655.405405
# 27  Sci&Tech    Yes    86.00         Mkt&HR  56.09  Not Placed  288655.405405
# 28  Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed  288655.405405
# 29  Sci&Tech     No    85.00         Mkt&HR  55.30  Not Placed  288655.405405
# 30  Sci&Tech     No    50.00        Mkt&Fin  59.47  Not Placed  288655.405405
# 31  Sci&Tech     No    75.00         Mkt&HR  67.99  Not Placed  288655.405405
# 32  Sci&Tech     No    79.00         Mkt&HR  59.24  Not Placed  288655.405405
# 33  Sci&Tech     No    58.00         Mkt&HR  66.53  Not Placed  288655.405405
# 34  Sci&Tech     No    64.00         Mkt&HR  58.32  Not Placed  288655.405405
# 35  Sci&Tech     No    63.00         Mkt&HR  60.02  Not Placed  288655.405405

# %%
# students with salary more than avg salary Comm&Mgmt dept

df[(df['degree_t']=='Comm&Mgmt')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     119    120      M   60.8  Central   68.4  Central  Commerce      64.6
# 1     177    178      F   73.0  Central   97.0   Others  Commerce      79.0
# 2       4      5      M   85.8  Central   73.6  Central  Commerce      73.3
# 3      95     96      M   73.0  Central   78.0   Others  Commerce      65.0
# 4     210    211      M   80.6   Others   82.0   Others  Commerce      77.6
# ..    ...    ...    ...    ...      ...    ...      ...       ...       ...
# 70    120    121      M   58.0   Others   40.0   Others   Science      59.0
# 71     29     30      M   62.0  Central   67.0  Central  Commerce      58.0
# 72     36     37      M   51.0  Central   44.0  Central  Commerce      57.0
# 73    136    137      F   47.0  Central   59.0  Central      Arts      64.0
# 74    214    215      M   62.0  Central   58.0   Others   Science      53.0
#
#      degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34      Placed  940000.000000
# 1   Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81      Placed  650000.000000
# 2   Comm&Mgmt     No    96.80        Mkt&Fin  55.50      Placed  425000.000000
# 3   Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16      Placed  420000.000000
# 4   Comm&Mgmt     No    91.00        Mkt&Fin  74.49      Placed  400000.000000
# ..        ...    ...      ...            ...    ...         ...            ...
# 70  Comm&Mgmt     No    73.00         Mkt&HR  58.81  Not Placed  288655.405405
# 71  Comm&Mgmt     No    77.00        Mkt&Fin  51.29  Not Placed  288655.405405
# 72  Comm&Mgmt     No    64.00        Mkt&Fin  51.45  Not Placed  288655.405405
# 73  Comm&Mgmt     No    78.00        Mkt&Fin  61.58  Not Placed  288655.405405
# 74  Comm&Mgmt     No    89.00         Mkt&HR  60.22  Not Placed  288655.405405
#
# [75 rows x 16 columns]

# %%
# maximum students placed are from comm&mgt

df.groupby(['degree_t'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <AxesSubplot:xlabel='degree_t'>

# %%
# Marketing and Finance specialisation are placed more

df.groupby(['specialisation'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <AxesSubplot:xlabel='specialisation'>

# %%
# females placed 35% and males 65%

df.groupby(['gender'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='status'>

# %%
# max female salary ~ 6,50,000

temp = df[df['gender']=='F']
temp[temp['salary']==max(temp['salary'])].style.background_gradient(cmap = 'plasma')
# Out:
# <style  type="text/css" >
# #T_4589c_row0_col0,#T_4589c_row0_col2,#T_4589c_row0_col4,#T_4589c_row0_col7,#T_4589c_row0_col10,#T_4589c_row0_col12,#T_4589c_row0_col14{
#             background-color:  #0d0887;
#             color:  #f1f1f1;
#         }</style><table id="T_4589c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sl_no</th>        <th class="col_heading level0 col1" >gender</th>        <th class="col_heading level0 col2" >ssc_p</th>        <th class="col_heading level0 col3" >ssc_b</th>        <th class="col_heading level0 col4" >hsc_p</th>        <th class="col_heading level0 col5" >hsc_b</th>        <th class="col_heading level0 col6" >hsc_s</th>        <th class="col_heading level0 col7" >degree_p</th>        <th class="col_heading level0 col8" >degree_t</th>        <th class="col_heading level0 col9" >workex</th>        <th class="col_heading level0 col10" >etest_p</th>        <th class="col_heading level0 col11" >specialisation</th>        <th class="col_heading level0 col12" >mba_p</th>        <th class="col_heading level0 col13" >status</th>        <th class="col_heading level0 col14" >salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4589c_level0_row0" class="row_heading level0 row0" >177</th>
#                         <td id="T_4589c_row0_col0" class="data row0 col0" >178</td>
#                         <td id="T_4589c_row0_col1" class="data row0 col1" >F</td>
#                         <td id="T_4589c_row0_col2" class="data row0 col2" >73.000000</td>
#                         <td id="T_4589c_row0_col3" class="data row0 col3" >Central</td>
#                         <td id="T_4589c_row0_col4" class="data row0 col4" >97.000000</td>
#                         <td id="T_4589c_row0_col5" class="data row0 col5" >Others</td>
#                         <td id="T_4589c_row0_col6" class="data row0 col6" >Commerce</td>
#                         <td id="T_4589c_row0_col7" class="data row0 col7" >79.000000</td>
#                         <td id="T_4589c_row0_col8" class="data row0 col8" >Comm&Mgmt</td>
#                         <td id="T_4589c_row0_col9" class="data row0 col9" >Yes</td>
#                         <td id="T_4589c_row0_col10" class="data row0 col10" >89.000000</td>
#                         <td id="T_4589c_row0_col11" class="data row0 col11" >Mkt&Fin</td>
#                         <td id="T_4589c_row0_col12" class="data row0 col12" >70.810000</td>
#                         <td id="T_4589c_row0_col13" class="data row0 col13" >Placed</td>
#                         <td id="T_4589c_row0_col14" class="data row0 col14" >650000.000000</td>
#             </tr>
#     </tbody></table>

# %%
df.groupby(['hsc_s'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%',figsize=(15,7))
# Out:
# <AxesSubplot:ylabel='status'>

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000

# %%
getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
len(getfinaldict['status']),len(getfinaldict['degree_t'])
# Out:
# (2, 3)

# %%
boolcols = [key for key,value in getfinaldict.items() if len(getfinaldict[key])==2]
tripcols = [key for key in list(getfinaldict.keys()) if key not in boolcols]

print(boolcols,tripcols)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'workex', 'specialisation', 'status'] ['hsc_s', 'degree_t']

# %% [markdown]
# ## Label Encoding process

# %%
def labelencode(le,col):
    
    df[col] = le.fit_transform(df[col])
    
    
getmappings = {}
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in list(getfinaldict.keys()):
    labelencode(le,col)
    getmappings[col] = dict(zip(le.classes_,le.transform(le.classes_)))
    

df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  etest_p  specialisation  mba_p  status         salary
# 0       0     55.0               1  58.80       1  270000.000000
# 1       1     86.5               0  66.28       1  200000.000000
# 2       0     75.0               0  57.80       1  250000.000000
# 3       0     66.0               1  59.43       0  288655.405405
# 4       0     96.8               0  55.50       1  425000.000000

# %%
# this was the internal mapping structure followed by label encoder for mapping

getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %%
# removing unwated columns

df = df.drop(['sl_no'],axis=1)
df.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      1  91.00      1      1     58.00         2       0
# 1       1  79.33      0  78.33      1      2     77.48         2       1
#
#    etest_p  specialisation  mba_p  status    salary
# 0     55.0               1  58.80       1  270000.0
# 1     86.5               0  66.28       1  200000.0

# %% [markdown]
# ## Numerical Columns EDA

# %%
numvars[1:]
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
import scipy.stats as stats

def getplots(df,col):
    
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')
    
    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm',plot=plt)
    
    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')
    
    plt.show()
    
    
for col in numvars[1:]:
    print(f'Distribution plots for col : {col} are shown ↓')
    getplots(df,col)
    print('='*10)
# Out:
# Distribution plots for col : ssc_p are shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : hsc_p are shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : degree_p are shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : etest_p are shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : mba_p are shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========
# Distribution plots for col : salary are shown ↓
# C:\Users\prabp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ==========

# %% [markdown]
# # Feature Selection

# %%
# checking for tightly correlated features

plt.figure(figsize=(15,7))
sn.heatmap(df.corr(),annot=True,cmap='plasma')
# Out:
# <AxesSubplot:>

# %%
'''
We will drop the salary column as well
coz after getting the placement we will get to know the salary right!

'''


data = df.copy()
test = data['status']
train = data.drop(['status','salary'],axis = 1)
train.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      1  91.00      1      1     58.00         2       0
# 1       1  79.33      0  78.33      1      2     77.48         2       1
#
#    etest_p  specialisation  mba_p
# 0     55.0               1  58.80
# 1     86.5               0  66.28

# %%
## extratrees classifier

from sklearn.ensemble import ExtraTreesClassifier
ec = ExtraTreesClassifier()
ec.fit(train,test)
# Out:
# ExtraTreesClassifier()

# %%
featbar = pd.Series(ec.feature_importances_,index=train.columns)
featbar.nlargest(7).plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
featbar.nlargest(7).plot(kind='pie',autopct='%1.0f%%',figsize = (15,7))
# Out:
# C:\Users\prabp\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# <AxesSubplot:ylabel='None'>

# %%
# mutual classif

from sklearn.feature_selection import mutual_info_classif
mc = mutual_info_classif(train,test)
ax = pd.Series(mc,index=train.columns)
ax.nlargest(7).plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
pd.Series(mc,index=train.columns).plot(kind = 'pie',autopct='%1.0f%%',figsize = (15,7))
# Out:
# C:\Users\prabp\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# <AxesSubplot:ylabel='None'>

# %%
'''
Selecting the top 10 contributing features in both cases
and then we will do the intersection of both the results
so that we will get atleast top 5 most contributing features!

'''

featcol = list(featbar.nlargest(10).index)
mutclasif = list(ax.nlargest(10).index)
commoncols = list(set(featcol).intersection(set(mutclasif)))
print(commoncols)
# Out:
# ['hsc_p', 'gender', 'ssc_b', 'ssc_p', 'mba_p', 'workex', 'degree_p', 'specialisation']

# %%
# selecting the common cols and will do training on these cols!
# these cols were selected as a nlargest result of 2 feature selection techniques!

train = df[commoncols]
train.head()
# Out:
#    hsc_p  gender  ssc_b  ssc_p  mba_p  workex  degree_p  specialisation
# 0  91.00       1      1  67.00  58.80       0     58.00               1
# 1  78.33       1      0  79.33  66.28       1     77.48               0
# 2  68.00       1      0  65.00  57.80       0     64.00               0
# 3  52.00       1      0  56.00  59.43       0     52.00               1
# 4  73.60       1      0  85.80  55.50       0     73.30               0

# %%
'''
From the above DF we notice that gender,specialisation,degree_t,workex are the 
categorical columns and they make sense isn't it?,for any placement drive
students are first filtered on basis of their boards,sem scores which in this case are {mba_p,ssc_p,degree_p,hsc_p}
and then workexperience also matters a lot!,then specialisation as well,gender is also important
because now-a-days few companies focus on women empowerment,so yes,all the features make perfect sense!

'''
getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %%
# renaming the cols

train = train[['gender','specialisation','degree_t','workex','ssc_p','hsc_p','degree_p','mba_p']]
train.columns = ['Gender','Specialisation','Techinal Degree','Work Experience','SSC_p','High School_p','Degree_p','MBA_p']
train.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-9eab62f1d1f6> in <module>
#       1 # renaming the cols
#       2
# ----> 3 train = train[['gender','specialisation','degree_t','workex','ssc_p','hsc_p','degree_p','mba_p']]
#       4 train.columns = ['Gender','Specialisation','Techinal Degree','Work Experience','SSC_p','High School_p','Degree_p','MBA_p']
#       5 train.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['degree_t'] not in index"

# %%
train['Techinal Degree'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Techinal Degree'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-5fbbcd585f05> in <module>
# ----> 1 train['Techinal Degree'].value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Techinal Degree'

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,RandomizedSearchCV,cross_val_score
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(train,test,test_size=0.2)
X_train.shape,X_test.shape
# Out:
# ((172, 8), (43, 8))

# %%
dc = DecisionTreeClassifier()
dc.fit(X_train,y_train)
plt.figure(figsize=(16,9))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns)
# Out:
# [Text(418.49999999999994, 458.6625, 'ssc_p <= 64.3\ngini = 0.407\nsamples = 172\nvalue = [49, 123]\nclass = Placed'),
#  Text(148.79999999999998, 397.5075, 'hsc_p <= 58.5\ngini = 0.464\nsamples = 63\nvalue = [40, 23]\nclass = Not_placed'),
#  Text(111.6, 336.3525, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = Not_placed'),
#  Text(185.99999999999997, 336.3525, 'mba_p <= 59.485\ngini = 0.493\nsamples = 41\nvalue = [18, 23]\nclass = Placed'),
#  Text(74.39999999999999, 275.1975, 'ssc_p <= 52.3\ngini = 0.397\nsamples = 22\nvalue = [6, 16]\nclass = Placed'),
#  Text(37.199999999999996, 214.04250000000002, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(111.6, 214.04250000000002, 'mba_p <= 52.295\ngini = 0.32\nsamples = 20\nvalue = [4, 16]\nclass = Placed'),
#  Text(74.39999999999999, 152.8875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(148.79999999999998, 152.8875, 'degree_p <= 59.895\ngini = 0.198\nsamples = 18\nvalue = [2, 16]\nclass = Placed'),
#  Text(111.6, 91.73250000000002, 'degree_p <= 57.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Placed'),
#  Text(74.39999999999999, 30.577499999999986, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Placed'),
#  Text(148.79999999999998, 30.577499999999986, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(185.99999999999997, 91.73250000000002, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Placed'),
#  Text(297.59999999999997, 275.1975, 'workex <= 0.5\ngini = 0.465\nsamples = 19\nvalue = [12, 7]\nclass = Not_placed'),
#  Text(260.4, 214.04250000000002, 'degree_p <= 66.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Not_placed'),
#  Text(223.2, 152.8875, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Not_placed'),
#  Text(297.59999999999997, 152.8875, 'degree_p <= 72.1\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not_placed'),
#  Text(260.4, 91.73250000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(334.79999999999995, 91.73250000000002, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not_placed'),
#  Text(334.79999999999995, 214.04250000000002, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Placed'),
#  Text(688.1999999999999, 397.5075, 'hsc_p <= 64.1\ngini = 0.152\nsamples = 109\nvalue = [9, 100]\nclass = Placed'),
#  Text(595.1999999999999, 336.3525, 'mba_p <= 66.38\ngini = 0.332\nsamples = 38\nvalue = [8, 30]\nclass = Placed'),
#  Text(520.8, 275.1975, 'ssc_p <= 68.0\ngini = 0.191\nsamples = 28\nvalue = [3, 25]\nclass = Placed'),
#  Text(483.59999999999997, 214.04250000000002, 'degree_p <= 68.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = Placed'),
#  Text(446.4, 152.8875, 'mba_p <= 57.83\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not_placed'),
#  Text(409.19999999999993, 91.73250000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(483.59999999999997, 91.73250000000002, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not_placed'),
#  Text(520.8, 152.8875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Placed'),
#  Text(557.9999999999999, 214.04250000000002, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]\nclass = Placed'),
#  Text(669.5999999999999, 275.1975, 'ssc_p <= 77.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = Not_placed'),
#  Text(632.4, 214.04250000000002, 'hsc_p <= 61.4\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not_placed'),
#  Text(595.1999999999999, 152.8875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(669.5999999999999, 152.8875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not_placed'),
#  Text(706.8, 214.04250000000002, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Placed'),
#  Text(781.1999999999999, 336.3525, 'mba_p <= 71.59\ngini = 0.028\nsamples = 71\nvalue = [1, 70]\nclass = Placed'),
#  Text(743.9999999999999, 275.1975, 'gini = 0.0\nsamples = 63\nvalue = [0, 63]\nclass = Placed'),
#  Text(818.3999999999999, 275.1975, 'mba_p <= 71.96\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = Placed'),
#  Text(781.1999999999999, 214.04250000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(855.5999999999999, 214.04250000000002, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Placed')]

# %%
costpath = dc.cost_complexity_pruning_path(train,test)
ccp_alpha,impurities = costpath.ccp_alphas,costpath.impurities

# %%
modellist = []
for alpha in ccp_alpha:
    dc = DecisionTreeClassifier(ccp_alpha=alpha)
    dc.fit(X_train,y_train)
    modellist.append(dc)

# %%
train_score = [clf.score(X_train,y_train) for clf in modellist]
test_score = [clf.score(X_test,y_test) for clf in modellist]

plt.xlabel('alpha_value')
plt.ylabel('accuracy')
plt.plot(ccp_alpha,train_score,label = 'train_score',marker = '+',color = 'magenta')
plt.plot(ccp_alpha,test_score,label = 'test_score',marker = '*',color = 'red')
plt.legend()
plt.show()

# %%
dc = DecisionTreeClassifier(ccp_alpha=0.0195)
dc.fit(X_train,y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns)
# Out:
# [Text(418.5, 342.46799999999996, 'ssc_p <= 64.3\ngini = 0.407\nsamples = 172\nvalue = [49, 123]\nclass = Placed'),
#  Text(279.0, 266.364, 'hsc_p <= 58.5\ngini = 0.464\nsamples = 63\nvalue = [40, 23]\nclass = Not_placed'),
#  Text(139.5, 190.26, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = Not_placed'),
#  Text(418.5, 190.26, 'mba_p <= 59.485\ngini = 0.493\nsamples = 41\nvalue = [18, 23]\nclass = Placed'),
#  Text(279.0, 114.156, 'gini = 0.397\nsamples = 22\nvalue = [6, 16]\nclass = Placed'),
#  Text(558.0, 114.156, 'workex <= 0.5\ngini = 0.465\nsamples = 19\nvalue = [12, 7]\nclass = Not_placed'),
#  Text(418.5, 38.051999999999964, 'gini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Not_placed'),
#  Text(697.5, 38.051999999999964, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Placed'),
#  Text(558.0, 266.364, 'gini = 0.152\nsamples = 109\nvalue = [9, 100]\nclass = Placed')]

# %% [markdown]
# # Hyperparameter Tuning

# %%
params = {
    'RandomForest':{
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators': [int(x) for x in np.linspace(start=1,stop=1200,num=10)],
            'max_depth':[int(x) for x in np.linspace(start=1,stop=30,num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },
    
    'logistic':{
        'model':LogisticRegression(),
        'params':{
            'penalty':['l1', 'l2', 'elasticnet'],
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,1e-3,0.025,0.25,0.50],
            'solver':['lbfgs','liblinear','saga','newton-cg'],
            'multi_class':['auto', 'ovr', 'multinomial'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    },
    'D-tree':{
        'model':DecisionTreeClassifier(),
        'params':{
            'criterion':['gini','entropy'],
            'splitter':['best','random'],
            'min_samples_split':[1,2,5,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },
    'SVM':{
        'model':SVC(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear','poly','sigmoid','rbf'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    }
}

# %%
scores = []
for model_name,mp in params.items():
    
    clf = RandomizedSearchCV(mp['model'],param_distributions=mp['params'],cv=5,n_iter=10,n_jobs=-1,scoring='accuracy')
    clf.fit(X_train,y_train)
    scores.append({
        'model_name':model_name,
        'best_score':clf.best_score_,
        'best_estimator':clf.best_estimator_
    })
# Out:
# C:\Users\prabp\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [0.83109244 0.85478992        nan 0.85462185 0.86621849 0.83142857
#         nan        nan 0.84907563        nan]
#   warnings.warn(
# C:\Users\prabp\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [0.77310924 0.80823529        nan        nan 0.81394958 0.72084034
#  0.78991597        nan 0.76168067        nan]
#   warnings.warn(

# %%
scores_df = pd.DataFrame(data = scores,columns = ['model_name','best_score','best_estimator'])
scores_df.head()
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest    0.872437  (DecisionTreeClassifier(ccp_alpha=0.0185, max_...
# 1      logistic    0.866218  LogisticRegression(C=0.5, max_iter=56, multi_c...
# 2        D-tree    0.813950  DecisionTreeClassifier(ccp_alpha=0.02, criteri...
# 3           SVM    0.848908  SVC(C=0.25, kernel='poly', max_iter=167, tol=0...

# %%
scores
# Out:
# [{'model_name': 'RandomForest',
#   'best_score': 0.8724369747899159,
#   'best_estimator': RandomForestClassifier(ccp_alpha=0.0185, max_depth=8, min_samples_leaf=5,
#                          min_samples_split=12, n_estimators=667)},
#  {'model_name': 'logistic',
#   'best_score': 0.8662184873949579,
#   'best_estimator': LogisticRegression(C=0.5, max_iter=56, multi_class='ovr', solver='liblinear',
#                      tol=1e-10)},
#  {'model_name': 'D-tree',
#   'best_score': 0.8139495798319327,
#   'best_estimator': DecisionTreeClassifier(ccp_alpha=0.02, criterion='entropy', max_features='auto',
#                          min_samples_leaf=5, min_samples_split=12)},
#  {'model_name': 'SVM',
#   'best_score': 0.8489075630252101,
#   'best_estimator': SVC(C=0.25, kernel='poly', max_iter=167, tol=0.0001)}]

# %%
# random forest model


rf = RandomForestClassifier(ccp_alpha=0.02, max_depth=30, max_features='sqrt',
                         min_samples_leaf=2, min_samples_split=12,
                         n_estimators=267)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.813953488372093

# %%
# logistic regression

lr = LogisticRegression(C=0.25, max_iter=111, multi_class='ovr', solver='newton-cg',
                     tol=1e-05)

lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8372093023255814

# %%
# decision tree

dc = DecisionTreeClassifier(ccp_alpha=0.019, criterion='entropy',
                         max_features='auto', min_samples_leaf=5,
                         min_samples_split=5, splitter='random')
dc.fit(X_train,y_train)
y_pred = dc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.627906976744186

# %%
print(metrics.classification_report(y_test,rf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.56      0.71        18
#            1       0.76      1.00      0.86        25
#
#     accuracy                           0.81        43
#    macro avg       0.88      0.78      0.79        43
# weighted avg       0.86      0.81      0.80        43

# %%
cn = metrics.confusion_matrix(y_test,rf.predict(X_test))
sn.heatmap(cn,annot=True,cmap='plasma')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Testing

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict([traindata[i]]))
    
predicted
# Out:
# [array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0])]

# %%
resultdf = train.copy()
resultdf['Actual'] = np.array(test)
resultdf['Predicted'] = np.array(predicted)
resultdf.head()
# Out:
#    hsc_p  gender  ssc_b  ssc_p  mba_p  workex  degree_p  specialisation  \
# 0  91.00       1      1  67.00  58.80       0     58.00               1
# 1  78.33       1      0  79.33  66.28       1     77.48               0
# 2  68.00       1      0  65.00  57.80       0     64.00               0
# 3  52.00       1      0  56.00  59.43       0     52.00               1
# 4  73.60       1      0  85.80  55.50       0     73.30               0
#
#    Actual  Predicted
# 0       1          1
# 1       1          1
# 2       1          1
# 3       0          0
# 4       1          1

# %%
resultdf['Actual'].value_counts()
# Out:
# 1    148
# 0     67
# Name: Actual, dtype: int64

# %%
resultdf['Predicted'].value_counts()
# Out:
# 1    169
# 0     46
# Name: Predicted, dtype: int64

# %%
getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %% [markdown]
# ### Predicted Probability

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict_proba([traindata[i]]))
    
predicted
# Out:
# [array([[0.2217338, 0.7782662]]),
#  array([[0.06578545, 0.93421455]]),
#  array([[0.21155374, 0.78844626]]),
#  array([[0.87673395, 0.12326605]]),
#  array([[0.07942089, 0.92057911]]),
#  array([[0.6579572, 0.3420428]]),
#  array([[0.68718283, 0.31281717]]),
#  array([[0.08626841, 0.91373159]]),
#  array([[0.08009398, 0.91990602]]),
#  array([[0.55124506, 0.44875494]]),
#  array([[0.38395271, 0.61604729]]),
#  array([[0.07382451, 0.92617549]]),
#  array([[0.79580425, 0.20419575]]),
#  array([[0.19847556, 0.80152444]]),
#  array([[0.78680332, 0.21319668]]),
#  array([[0.08020458, 0.91979542]]),
#  array([[0.18366109, 0.81633891]]),
#  array([[0.59176412, 0.40823588]]),
#  array([[0.50895412, 0.49104588]]),
#  array([[0.2087496, 0.7912504]]),
#  array([[0.21234691, 0.78765309]]),
#  array([[0.09544664, 0.90455336]]),
#  array([[0.18595401, 0.81404599]]),
#  array([[0.12808513, 0.87191487]]),
#  array([[0.08546052, 0.91453948]]),
#  array([[0.71075163, 0.28924837]]),
#  array([[0.06837503, 0.93162497]]),
#  array([[0.20726568, 0.79273432]]),
#  array([[0.06793937, 0.93206063]]),
#  array([[0.54769308, 0.45230692]]),
#  array([[0.19273709, 0.80726291]]),
#  array([[0.49573815, 0.50426185]]),
#  array([[0.29741013, 0.70258987]]),
#  array([[0.08867795, 0.91132205]]),
#  array([[0.85082005, 0.14917995]]),
#  array([[0.11503913, 0.88496087]]),
#  array([[0.86222915, 0.13777085]]),
#  array([[0.12927594, 0.87072406]]),
#  array([[0.18304176, 0.81695824]]),
#  array([[0.17212435, 0.82787565]]),
#  array([[0.09571657, 0.90428343]]),
#  array([[0.20240404, 0.79759596]]),
#  array([[0.76228718, 0.23771282]]),
#  array([[0.08594981, 0.91405019]]),
#  array([[0.07292509, 0.92707491]]),
#  array([[0.18477835, 0.81522165]]),
#  array([[0.23627721, 0.76372279]]),
#  array([[0.2625175, 0.7374825]]),
#  array([[0.24899339, 0.75100661]]),
#  array([[0.84880665, 0.15119335]]),
#  array([[0.09997667, 0.90002333]]),
#  array([[0.65449058, 0.34550942]]),
#  array([[0.8817623, 0.1182377]]),
#  array([[0.11976742, 0.88023258]]),
#  array([[0.16049568, 0.83950432]]),
#  array([[0.30669669, 0.69330331]]),
#  array([[0.48675432, 0.51324568]]),
#  array([[0.08964227, 0.91035773]]),
#  array([[0.10692191, 0.89307809]]),
#  array([[0.33771873, 0.66228127]]),
#  array([[0.07231342, 0.92768658]]),
#  array([[0.08167707, 0.91832293]]),
#  array([[0.10477493, 0.89522507]]),
#  array([[0.46531267, 0.53468733]]),
#  array([[0.07833442, 0.92166558]]),
#  array([[0.83792469, 0.16207531]]),
#  array([[0.08522388, 0.91477612]]),
#  array([[0.08308464, 0.91691536]]),
#  array([[0.40226102, 0.59773898]]),
#  array([[0.07221001, 0.92778999]]),
#  array([[0.19583004, 0.80416996]]),
#  array([[0.08930684, 0.91069316]]),
#  array([[0.1080866, 0.8919134]]),
#  array([[0.09055548, 0.90944452]]),
#  array([[0.3393763, 0.6606237]]),
#  array([[0.42807443, 0.57192557]]),
#  array([[0.12301634, 0.87698366]]),
#  array([[0.13230201, 0.86769799]]),
#  array([[0.10900125, 0.89099875]]),
#  array([[0.23674238, 0.76325762]]),
#  array([[0.11250578, 0.88749422]]),
#  array([[0.0979645, 0.9020355]]),
#  array([[0.28397745, 0.71602255]]),
#  array([[0.06671295, 0.93328705]]),
#  array([[0.08073883, 0.91926117]]),
#  array([[0.0904708, 0.9095292]]),
#  array([[0.34434877, 0.65565123]]),
#  array([[0.84791255, 0.15208745]]),
#  array([[0.19055671, 0.80944329]]),
#  array([[0.08104368, 0.91895632]]),
#  array([[0.09562636, 0.90437364]]),
#  array([[0.79998179, 0.20001821]]),
#  array([[0.28279486, 0.71720514]]),
#  array([[0.62510144, 0.37489856]]),
#  array([[0.38712787, 0.61287213]]),
#  array([[0.08759791, 0.91240209]]),
#  array([[0.08353045, 0.91646955]]),
#  array([[0.35645352, 0.64354648]]),
#  array([[0.1319511, 0.8680489]]),
#  array([[0.46476762, 0.53523238]]),
#  array([[0.66683543, 0.33316457]]),
#  array([[0.2528268, 0.7471732]]),
#  array([[0.08847132, 0.91152868]]),
#  array([[0.07875502, 0.92124498]]),
#  array([[0.12958119, 0.87041881]]),
#  array([[0.51034959, 0.48965041]]),
#  array([[0.82372348, 0.17627652]]),
#  array([[0.09905253, 0.90094747]]),
#  array([[0.2187785, 0.7812215]]),
#  array([[0.40597112, 0.59402888]]),
#  array([[0.12905979, 0.87094021]]),
#  array([[0.87641556, 0.12358444]]),
#  array([[0.45857892, 0.54142108]]),
#  array([[0.09098243, 0.90901757]]),
#  array([[0.11959731, 0.88040269]]),
#  array([[0.11868249, 0.88131751]]),
#  array([[0.07373807, 0.92626193]]),
#  array([[0.084629, 0.915371]]),
#  array([[0.08004229, 0.91995771]]),
#  array([[0.21303721, 0.78696279]]),
#  array([[0.84827936, 0.15172064]]),
#  array([[0.17392481, 0.82607519]]),
#  array([[0.09270644, 0.90729356]]),
#  array([[0.11458117, 0.88541883]]),
#  array([[0.13215779, 0.86784221]]),
#  array([[0.09335771, 0.90664229]]),
#  array([[0.09697777, 0.90302223]]),
#  array([[0.12590893, 0.87409107]]),
#  array([[0.09179397, 0.90820603]]),
#  array([[0.0720303, 0.9279697]]),
#  array([[0.58628001, 0.41371999]]),
#  array([[0.23446864, 0.76553136]]),
#  array([[0.1359998, 0.8640002]]),
#  array([[0.09898707, 0.90101293]]),
#  array([[0.07247651, 0.92752349]]),
#  array([[0.34438493, 0.65561507]]),
#  array([[0.66387418, 0.33612582]]),
#  array([[0.12405079, 0.87594921]]),
#  array([[0.10015903, 0.89984097]]),
#  array([[0.13625325, 0.86374675]]),
#  array([[0.0781322, 0.9218678]]),
#  array([[0.39287886, 0.60712114]]),
#  array([[0.08097336, 0.91902664]]),
#  array([[0.09183588, 0.90816412]]),
#  array([[0.85026914, 0.14973086]]),
#  array([[0.10816031, 0.89183969]]),
#  array([[0.24518787, 0.75481213]]),
#  array([[0.12153248, 0.87846752]]),
#  array([[0.19473388, 0.80526612]]),
#  array([[0.58098838, 0.41901162]]),
#  array([[0.19655236, 0.80344764]]),
#  array([[0.11197366, 0.88802634]]),
#  array([[0.12178866, 0.87821134]]),
#  array([[0.39130416, 0.60869584]]),
#  array([[0.44780789, 0.55219211]]),
#  array([[0.46572089, 0.53427911]]),
#  array([[0.11690669, 0.88309331]]),
#  array([[0.26881297, 0.73118703]]),
#  array([[0.23436524, 0.76563476]]),
#  array([[0.88283836, 0.11716164]]),
#  array([[0.12779401, 0.87220599]]),
#  array([[0.8714355, 0.1285645]]),
#  array([[0.06578545, 0.93421455]]),
#  array([[0.4400917, 0.5599083]]),
#  array([[0.21733322, 0.78266678]]),
#  array([[0.30292792, 0.69707208]]),
#  array([[0.31373847, 0.68626153]]),
#  array([[0.12756004, 0.87243996]]),
#  array([[0.72112328, 0.27887672]]),
#  array([[0.84737341, 0.15262659]]),
#  array([[0.57873874, 0.42126126]]),
#  array([[0.06670185, 0.93329815]]),
#  array([[0.28222004, 0.71777996]]),
#  array([[0.87632239, 0.12367761]]),
#  array([[0.31954192, 0.68045808]]),
#  array([[0.38491596, 0.61508404]]),
#  array([[0.50362983, 0.49637017]]),
#  array([[0.07229679, 0.92770321]]),
#  array([[0.37788244, 0.62211756]]),
#  array([[0.28189387, 0.71810613]]),
#  array([[0.10898472, 0.89101528]]),
#  array([[0.43776892, 0.56223108]]),
#  array([[0.46403182, 0.53596818]]),
#  array([[0.11256775, 0.88743225]]),
#  array([[0.56871774, 0.43128226]]),
#  array([[0.11467545, 0.88532455]]),
#  array([[0.68579911, 0.31420089]]),
#  array([[0.08137619, 0.91862381]]),
#  array([[0.77432405, 0.22567595]]),
#  array([[0.37915437, 0.62084563]]),
#  array([[0.50265477, 0.49734523]]),
#  array([[0.10987993, 0.89012007]]),
#  array([[0.10576236, 0.89423764]]),
#  array([[0.31462571, 0.68537429]]),
#  array([[0.83928834, 0.16071166]]),
#  array([[0.08172382, 0.91827618]]),
#  array([[0.07794929, 0.92205071]]),
#  array([[0.34132197, 0.65867803]]),
#  array([[0.28347583, 0.71652417]]),
#  array([[0.22022699, 0.77977301]]),
#  array([[0.16185855, 0.83814145]]),
#  array([[0.61243791, 0.38756209]]),
#  array([[0.12868702, 0.87131298]]),
#  array([[0.53986724, 0.46013276]]),
#  array([[0.0731048, 0.9268952]]),
#  array([[0.25865481, 0.74134519]]),
#  array([[0.83827762, 0.16172238]]),
#  array([[0.15195775, 0.84804225]]),
#  array([[0.61453124, 0.38546876]]),
#  array([[0.23304691, 0.76695309]]),
#  array([[0.08824478, 0.91175522]]),
#  array([[0.25474989, 0.74525011]]),
#  array([[0.08388628, 0.91611372]]),
#  array([[0.2501908, 0.7498092]]),
#  array([[0.69231144, 0.30768856]])]

# %%
predicted[0][0],predicted[0][0][0],predicted[0][0][1]
# Out:
# (array([0.2217338, 0.7782662]), 0.22173380479642665, 0.7782661952035733)

# %%
resultdf['Prob_not_getting_placed'] = np.array([predicted[i][0][0] for i in range(len(predicted))])
resultdf['Prob_getting_placed'] = np.array([predicted[i][0][1] for i in range(len(predicted))])
resultdf
# Out:
#      hsc_p  gender  ssc_b  ssc_p  mba_p  workex  degree_p  specialisation  \
# 0    91.00       1      1  67.00  58.80       0     58.00               1
# 1    78.33       1      0  79.33  66.28       1     77.48               0
# 2    68.00       1      0  65.00  57.80       0     64.00               0
# 3    52.00       1      0  56.00  59.43       0     52.00               1
# 4    73.60       1      0  85.80  55.50       0     73.30               0
# ..     ...     ...    ...    ...    ...     ...       ...             ...
# 210  82.00       1      1  80.60  74.49       0     77.60               0
# 211  60.00       1      1  58.00  53.62       0     72.00               0
# 212  67.00       1      1  67.00  69.72       1     73.00               0
# 213  66.00       0      1  74.00  60.23       0     58.00               1
# 214  58.00       1      0  62.00  60.22       0     53.00               1
#
#      Actual  Predicted  Prob_not_getting_placed  Prob_getting_placed
# 0         1          1                 0.221734             0.778266
# 1         1          1                 0.065785             0.934215
# 2         1          1                 0.211554             0.788446
# 3         0          0                 0.876734             0.123266
# 4         1          1                 0.079421             0.920579
# ..      ...        ...                      ...                  ...
# 210       1          1                 0.088245             0.911755
# 211       1          1                 0.254750             0.745250
# 212       1          1                 0.083886             0.916114
# 213       1          1                 0.250191             0.749809
# 214       0          0                 0.692311             0.307689
#
# [215 rows x 12 columns]

# %%
# saving the model

import pickle
file = open('campusplacementpredictor.pkl','wb')
pickle.dump(rf,file)
file.close()

# %% [markdown]
# ### Conclusions
#
#
#  + 16 records were missclassified,resulting in the accuracy of 93% on testing data
#  + Random Forest model gave the best results
